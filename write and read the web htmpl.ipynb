# %%
import json

# %%
values=requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")

# %%
import requests

# %%
values1=values.json()

# %%
values1
# Out:
# {'items': [{'tags': ['python',
#     'pandas',
#     'dataframe',
#     'numpy',
#     'sklearn-pandas'],
#    'owner': {'account_id': 23741690,
#     'reputation': 47,
#     'user_id': 17759657,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b36fcdcebc8592ae3112c70c05f0f626?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'sara hajmirzaeyan',
#     'link': 'https://stackoverflow.com/users/17759657/sara-hajmirzaeyan'},
#    'is_answered': False,
#    'view_count': 1,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1648457534,
#    'creation_date': 1648457534,
#    'question_id': 71644718,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71644718/i-wrote-this-code-and-received-this-error-how-should-i-fix-this',
#    'title': 'I wrote this code and received this error. How should I fix this?'},
#   {'tags': ['mysql', 'sql', 'switch-statement'],
# ...

# %%
import pandas as pd

# %%
values2=pd.json_normalize(values1["items"])

# %%
values2
# Out:
#                                                  tags  is_answered  \
# 0   [python, pandas, dataframe, numpy, sklearn-pan...        False
# 1                      [mysql, sql, switch-statement]        False
# 2                      [solidity, hardhat, etherscan]        False
# 3                              [c#, gaps-and-islands]        False
# 4                              [java, regex, extract]        False
# 5   [python, coordinates, geojson, coordinate-syst...        False
# 6               [laravel-5, seeding, laravel-seeding]        False
# 7                                        [memgraphdb]        False
# 8   [tensorflow, binary, cuda, dynamic-library, co...        False
# 9   [python, machine-learning, scikit-learn, rando...        False
# 10  [python, pandas, dataframe, merge, concatenation]        False
# 11                                     [java, okhttp]         True
# 12                                       [typescript]         True
# ...

# %%
values3=pd.json_normalize(values2["tags"])

# %%
values3
# Out:
#      0     1     2     3     4
# 0   {}    {}    {}    {}    {}
# 1   {}    {}    {}  None  None
# 2   {}    {}    {}  None  None
# 3   {}    {}  None  None  None
# 4   {}    {}    {}  None  None
# 5   {}    {}    {}    {}    {}
# 6   {}    {}    {}  None  None
# 7   {}  None  None  None  None
# 8   {}    {}    {}    {}    {}
# 9   {}    {}    {}    {}    {}
# 10  {}    {}    {}    {}    {}
# 11  {}    {}  None  None  None
# 12  {}  None  None  None  None
# 13  {}    {}    {}    {}    {}
# 14  {}  None  None  None  None
# 15  {}    {}  None  None  None
# 16  {}    {}    {}    {}    {}
# 17  {}    {}    {}    {}    {}
# 18  {}    {}  None  None  None
# 19  {}    {}    {}    {}    {}
# 20  {}    {}    {}  None  None
# 21  {}  None  None  None  None
# 22  {}    {}    {}    {}    {}
# 23  {}  None  None  None  None
# 24  {}    {}  None  None  None
# 25  {}    {}  None  None  None
# 26  {}    {}    {}    {}    {}
# 27  {}    {}    {}    {}    {}
# 28  {}    {}    {}  None  None
# ...

# %%
ht=<!doctype html>
<html dir="ltr" lang="en">
  <head>
    <meta charset="utf-8">
    <title>New Tab</title>
    <style>
      body {
        background: #35363A;
        margin: 0;
      }

      #backgroundImage {
        border: none;
        height: 100%;
        pointer-events: none;
        position: fixed;
        top: 0;
        visibility: hidden;
        width: 100%;
      }

      [show-background-image] #backgroundImage {
        visibility: visible;
      }
    </style>
  </head>
  <body>
    <iframe id="backgroundImage" src=""></iframe>
    <ntp-app></ntp-app>
    <script type="module" src="new_tab_page.js"></script>
    <link rel="stylesheet" href="chrome://resources/css/text_defaults_md.css">
    <link rel="stylesheet" href="shared_vars.css">
  </body>
</html>

# %%
import webbrowser

# %%
f=open('suvanesh.html',"w")
value= """<!doctype html>
<html dir="ltr" lang="en">
  <head>
    <meta charset="utf-8">
    <title>New Tab</title>
    <style>
      body {
        background: #35363A;
        margin: 0;
      }

      #backgroundImage {
        border: none;
        height: 100%;
        pointer-events: none;
        position: fixed;
        top: 0;
        visibility: hidden;
        width: 100%;
      }

      [show-background-image] #backgroundImage {
        visibility: visible;
      }
    </style>
  </head>
  <body>
    <iframe id="backgroundImage" src=""></iframe>
    <ntp-app></ntp-app>
    <script type="module" src="new_tab_page.js"></script>
    <link rel="stylesheet" href="chrome://resources/css/text_defaults_md.css">
    <link rel="stylesheet" href="shared_vars.css">
  </body>
</html>"""
f.write(value)
f.close()

# %%
webbrowser.open_new_tab("suvanesh.html")
# Out:
# True

# %%
from bs4 import BeautifulSoup

# %%
with open("suvanesh.html","r") as html_file:
    content= html_file.read()
    print(content)
# Out:
# <!doctype html>
# <html dir="ltr" lang="en">
#   <head>
#     <meta charset="utf-8">
#     <title>New Tab</title>
#     <style>
#       body {
#         background: #35363A;
#         margin: 0;
#       }
#
#       #backgroundImage {
#         border: none;
#         height: 100%;
#         pointer-events: none;
#         position: fixed;
#         top: 0;
#         visibility: hidden;
#         width: 100%;
#       }
#
#       [show-background-image] #backgroundImage {
#         visibility: visible;
#       }
#     </style>
#   </head>
#   <body>
#     <iframe id="backgroundImage" src=""></iframe>
#     <ntp-app></ntp-app>
#     <script type="module" src="new_tab_page.js"></script>
#     <link rel="stylesheet" href="chrome://resources/css/text_defaults_md.css">
#     <link rel="stylesheet" href="shared_vars.css">
#   </body>
# </html>

# %%
with open("suvanesh.html","r") as html_f:
    content=html_f.read()
    soup=BeautifulSoup(content)
    print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    New Tab
#   </title>
#   <style>
#    body {
#         background: #35363A;
#         margin: 0;
#       }
#
#       #backgroundImage {
#         border: none;
#         height: 100%;
#         pointer-events: none;
#         position: fixed;
#         top: 0;
#         visibility: hidden;
#         width: 100%;
#       }
#
#       [show-background-image] #backgroundImage {
#         visibility: visible;
#       }
#   </style>
#  </head>
#  <body>
#   <iframe id="backgroundImage" src="">
#   </iframe>
#   <ntp-app>
#   </ntp-app>
#   <script src="new_tab_page.js" type="module">
#   </script>
#   <link href="chrome://resources/css/text_defaults_md.css" rel="stylesheet"/>
#   <link href="shared_vars.css" rel="stylesheet"/>
#  </body>
# </html>

# %%
with open("suvanesh.html","r") as html_f:
    content=html_f.read()
    soup=BeautifulSoup(content)
    img=soup.find_all("ifram")
    print(img)
# Out:
# [<iframe id="backgroundImage" src=""></iframe>]
