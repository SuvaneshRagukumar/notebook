# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url="https://en.wikipedia.org/wiki/List_of_prime_ministers_of_India"
table_class="wikitable sortable jquery-tablesorter"
response=requests.get(url)
soup=BeautifulSoup(response.text,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of prime ministers of India - Wikipedia</title>
# ...

# %%
indiatable=soup.find('table',{'class':"wikitable"})
print(indiatable)
# Out:
# <table class="wikitable sortable" id="pm_list" style="width:100%; text-align:center">
# <tbody><tr>
# ...

# %%
df=pd.read_html(str(indiatable))
df=pd.DataFrame(df[0])
df.columns =['No','No.1','N0','Name','Party','Took Office','Left Office','lig','thing','twenty','king','queen']

# %%
df
# Out:
#       No  No.1  N0                                           Name  \
# 0      1   NaN NaN                    Jawaharlal Nehru(1889–1964)
# 1      1   NaN NaN                    Jawaharlal Nehru(1889–1964)
# 2      1   NaN NaN                    Jawaharlal Nehru(1889–1964)
# 3      1   NaN NaN                    Jawaharlal Nehru(1889–1964)
# 4      -   NaN NaN                    Gulzarilal Nanda(1898–1998)
# 5      2   NaN NaN                 Lal Bahadur Shastri(1904–1966)
# 6      -   NaN NaN                    Gulzarilal Nanda(1898–1998)
# 7      3   NaN NaN                       Indira Gandhi(1917–1984)
# 8      3   NaN NaN                       Indira Gandhi(1917–1984)
# 9      3   NaN NaN                       Indira Gandhi(1917–1984)
# 10     4   NaN NaN                       Morarji Desai(1896–1995)
# 11     5   NaN NaN              Chaudhary Charan Singh(1902–1987)
# 12   (3)   NaN NaN                       Indira Gandhi(1917–1984)
# ...

# %%
df_split=df["lig"].str.split(",",n=1,expand=True)
df_split
# Out:
#            0          1
# 0   16 years   286 days
# 1   16 years   286 days
# 2   16 years   286 days
# 3   16 years   286 days
# 4    13 days       None
# 5     1 year   216 days
# 6    13 days       None
# 7   11 years    59 days
# 8   11 years    59 days
# 9   11 years    59 days
# 10   2 years   126 days
# 11  170 days       None
# 12   4 years   291 days
# 13   5 years    32 days
# 14   5 years    32 days
# 15  343 days       None
# 16  223 days       None
# 17   4 years   330 days
# 18   16 days       None
# 19  324 days       None
# 20  332 days       None
# 21   6 years    64 days
# 22   6 years    64 days
# 23  10 years     4 days
# 24  10 years     4 days
# 25   7 years   306 days
# 26   7 years   306 days

# %%
df["Days"]=df_split[1]
df["Years"]=df_split[0]
df.head()
# Out:
#   No No.1   N0                         Name                     Party  \
# 0  1  0 0  0 0  Jawaharlal Nehru(1889–1964)  Indian National Congress
# 1  1  0 0  0 0  Jawaharlal Nehru(1889–1964)  Indian National Congress
# 2  1  0 0  0 0  Jawaharlal Nehru(1889–1964)  Indian National Congress
# 3  1  0 0  0 0  Jawaharlal Nehru(1889–1964)  Indian National Congress
# 4  -  0 0  0 0  Gulzarilal Nanda(1898–1998)  Indian National Congress
#
#       Took Office    Left Office                 lig                    thing  \
# 0  15 August 1947  15 April 1952  16 years, 286 days  Constituent Assembly[f]
# 1   15 April 1952  17 April 1957  16 years, 286 days                      1st
# 2   17 April 1957   2 April 1962  16 years, 286 days                      2nd
# 3    2 April 1962   27 May 1964†  16 years, 286 days                      3rd
# 4     27 May 1964    9 June 1964             13 days                      3rd
#
#       twenty                           king queen       Days     Years  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'years'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# #

# %%
# Out:
#       No No.1   N0                                           Name  \
# 0      1  0 0  0 0                    Jawaharlal Nehru(1889–1964)
# 1      1  0 0  0 0                    Jawaharlal Nehru(1889–1964)
# 2      1  0 0  0 0                    Jawaharlal Nehru(1889–1964)
# 3      1  0 0  0 0                    Jawaharlal Nehru(1889–1964)
# 4      -  0 0  0 0                    Gulzarilal Nanda(1898–1998)
# 5      2  0 0  0 0                 Lal Bahadur Shastri(1904–1966)
# 6      -  0 0  0 0                    Gulzarilal Nanda(1898–1998)
# 7      3  0 0  0 0                       Indira Gandhi(1917–1984)
# 8      3  0 0  0 0                       Indira Gandhi(1917–1984)
# 9      3  0 0  0 0                       Indira Gandhi(1917–1984)
# 10     4  0 0  0 0                       Morarji Desai(1896–1995)
# 11     5  0 0  0 0              Chaudhary Charan Singh(1902–1987)
# 12   (3)  0 0  0 0                       Indira Gandhi(1917–1984)
# ...

# %%
df2=df[['Name','Party','Took Office','Left Office']]

# %%
df2
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df2['Took Office']=df2['Took Office'].str.replace('[[§]]','')
# Out:
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/391784363.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['Took Office']=df2['Took Office'].str.replace('[[§]]','')
# /Users/suvaneshragukumar/opt/anaconda3/lib/python3.9/site-packages/pandas/core/strings/object_array.py:156: FutureWarning: Possible nested set at position 1
#   pat = re.compile(pat, flags=flags)
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/391784363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Took Office']=df2['Took Office'].str.replace('[[§]]','')

# %%
df2['Took Office']=df2['Took Office'].str.replace('[','')
# Out:
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/2465175143.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['Took Office']=df2['Took Office'].str.replace('[','')
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/2465175143.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Took Office']=df2['Took Office'].str.replace('[','')

# %%
df2
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df2['Left Office']=df2['Left Office'].str.replace('[NC]','')
# Out:
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/634003453.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['Left Office']=df2['Left Office'].str.replace('[NC]','')
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/634003453.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Left Office']=df2['Left Office'].str.replace('[NC]','')

# %%
df2
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df2['Left Office']=df2['Left Office'].str.replace('[RES]','')
# Out:
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/1354865791.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['Left Office']=df2['Left Office'].str.replace('[RES]','')
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/1354865791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Left Office']=df2['Left Office'].str.replace('[RES]','')

# %%
df2
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df2['Left Office']=df2['Left Office'].str.replace('[[]','')
# Out:
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/468825675.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['Left Office']=df2['Left Office'].str.replace('[[]','')
# /Users/suvaneshragukumar/opt/anaconda3/lib/python3.9/site-packages/pandas/core/strings/object_array.py:156: FutureWarning: Possible nested set at position 1
#   pat = re.compile(pat, flags=flags)
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/468825675.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Left Office']=df2['Left Office'].str.replace('[[]','')

# %%
df2
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df2['Left Office']=df2['Left Office'].str.replace('[]]','')
# Out:
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/136721263.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['Left Office']=df2['Left Office'].str.replace('[]]','')
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/136721263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Left Office']=df2['Left Office'].str.replace('[]]','')

# %%
df2
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df2['Left Office']=df2['Left Office'].str.replace('[†]','')
# Out:
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/1631754665.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['Left Office']=df2['Left Office'].str.replace('[†]','')
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/1631754665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Left Office']=df2['Left Office'].str.replace('[†]','')

# %%
df2
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df2.drop(26)
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df2["Name"]=df2["Name"].str.split('(').str[0]
# Out:
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/2422806510.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Name"]=df2["Name"].str.split('(').str[0]

# %%
df2
# Out:
#                                    Name                               Party  \
# 0                      Jawaharlal Nehru            Indian National Congress
# 1                      Jawaharlal Nehru            Indian National Congress
# 2                      Jawaharlal Nehru            Indian National Congress
# 3                      Jawaharlal Nehru            Indian National Congress
# 4                      Gulzarilal Nanda            Indian National Congress
# 5                   Lal Bahadur Shastri            Indian National Congress
# 6                      Gulzarilal Nanda            Indian National Congress
# 7                         Indira Gandhi            Indian National Congress
# 8                         Indira Gandhi        Indian National Congress (R)
# 9                         Indira Gandhi        Indian National Congress (R)
# 10                        Morarji Desai                        Janata Party
# ...

# %%
df2.columns =['Name','Party','Took_Office','Left_Office']
df2
# Out:
#                                    Name                               Party  \
# 0                      Jawaharlal Nehru            Indian National Congress
# 1                      Jawaharlal Nehru            Indian National Congress
# 2                      Jawaharlal Nehru            Indian National Congress
# 3                      Jawaharlal Nehru            Indian National Congress
# 4                      Gulzarilal Nanda            Indian National Congress
# 5                   Lal Bahadur Shastri            Indian National Congress
# 6                      Gulzarilal Nanda            Indian National Congress
# 7                         Indira Gandhi            Indian National Congress
# 8                         Indira Gandhi        Indian National Congress (R)
# 9                         Indira Gandhi        Indian National Congress (R)
# 10                        Morarji Desai                        Janata Party
# ...

# %%
df2.drop(26)
# Out:
#                                    Name                               Party  \
# 0                      Jawaharlal Nehru            Indian National Congress
# 1                      Jawaharlal Nehru            Indian National Congress
# 2                      Jawaharlal Nehru            Indian National Congress
# 3                      Jawaharlal Nehru            Indian National Congress
# 4                      Gulzarilal Nanda            Indian National Congress
# 5                   Lal Bahadur Shastri            Indian National Congress
# 6                      Gulzarilal Nanda            Indian National Congress
# 7                         Indira Gandhi            Indian National Congress
# 8                         Indira Gandhi        Indian National Congress (R)
# 9                         Indira Gandhi        Indian National Congress (R)
# 10                        Morarji Desai                        Janata Party
# ...

# %%
df2['Took_Office'] = pd.to_datetime(df2['Took_Office'], infer_datetime_format=True)
df2
# Out:
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_6896/1800543700.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Took_Office'] = pd.to_datetime(df2['Took_Office'], infer_datetime_format=True)
#                                    Name                               Party  \
# 0                      Jawaharlal Nehru            Indian National Congress
# 1                      Jawaharlal Nehru            Indian National Congress
# 2                      Jawaharlal Nehru            Indian National Congress
# 3                      Jawaharlal Nehru            Indian National Congress
# 4                      Gulzarilal Nanda            Indian National Congress
# ...

# %%
df3=df2.drop(26)
df3
# Out:
#                                    Name                               Party  \
# 0                      Jawaharlal Nehru            Indian National Congress
# 1                      Jawaharlal Nehru            Indian National Congress
# 2                      Jawaharlal Nehru            Indian National Congress
# 3                      Jawaharlal Nehru            Indian National Congress
# 4                      Gulzarilal Nanda            Indian National Congress
# 5                   Lal Bahadur Shastri            Indian National Congress
# 6                      Gulzarilal Nanda            Indian National Congress
# 7                         Indira Gandhi            Indian National Congress
# 8                         Indira Gandhi        Indian National Congress (R)
# 9                         Indira Gandhi        Indian National Congress (R)
# 10                        Morarji Desai                        Janata Party
# ...

# %%
df3.loc[[15],"Left_Office"]='10 November 1990'

# %%
df3['Left_Office'] = pd.to_datetime(df3['Left_Office'], infer_datetime_format=True)
df3
# Out:
#                                    Name                               Party  \
# 0                      Jawaharlal Nehru            Indian National Congress
# 1                      Jawaharlal Nehru            Indian National Congress
# 2                      Jawaharlal Nehru            Indian National Congress
# 3                      Jawaharlal Nehru            Indian National Congress
# 4                      Gulzarilal Nanda            Indian National Congress
# 5                   Lal Bahadur Shastri            Indian National Congress
# 6                      Gulzarilal Nanda            Indian National Congress
# 7                         Indira Gandhi            Indian National Congress
# 8                         Indira Gandhi        Indian National Congress (R)
# 9                         Indira Gandhi        Indian National Congress (R)
# 10                        Morarji Desai                        Janata Party
# ...

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
connection=pymysql.connect(host="localhost",user="root",password="suvanesh@27",db="task")

# %%
cursor=connection.cursor()

# %%
cols = "`,`".join([str(i) for i in df3.columns.tolist()])

# Insert DataFrame recrds one by one.
for i,row in df3.iterrows():
    sql = "INSERT INTO `prime` (`" +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"
    cursor.execute(sql, tuple(row))

    # the connection is not autocommitted by default, so we must commit to save our changes
    connection.commit()

# %%
sql = "SELECT * FROM `list`"
cursor.execute(sql)

# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (20210307, 56, 28756489, 74582825, 11808, 40199, 776361, 8134, 45475, 2802, 4281, '2021-03-07T24:00:00Z', 515151, 776361, 363825123, '2021-03-07T24:00:00Z', None, 0, 0, 842, 726, 131835, 41835, 1170059, 'a80d0063822e251249fd9a44730c49cb23defd83')
# (20210306, 56, 28714654, 74450990, 11783, 41401, 775635, 8409, 45453, 2811, 4280, '2021-03-06T24:00:00Z', 514309, 775635, 362655064, '2021-03-06T24:00:00Z', None, 0, 0, 1680, 503, 143835, 60015, 1430992, 'dae5e558c24adb86686bbd58c08cce5f610b8bb0')
# (20210305, 56, 28654639, 74307155, 12213, 42541, 775132, 8634, 45373, 2889, 4275, '2021-03-05T24:00:00Z', 512629, 775132, 361224072, '2021-03-05T24:00:00Z', None, 0, 0, 2221, 2781, 271917, 68787, 1744417, '724844c01659d0103801c57c0f72bf8cc8ab025c')
# ...

# %%
connection.close()
