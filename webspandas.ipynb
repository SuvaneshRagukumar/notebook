# %%
import pandas as pd

# %%
f=pd.read_html("https://en.wikipedia.org/wiki/List_of_prime_ministers_of_India")

# %%
f[2]
# Out:
#    BJP (2)[b] INC/INC(I)/INC(R) [c] (6+1 acting[d]) JD (3) JP (1) JP(S) (1) SJP(R) (1)  \
#                                                                                     No
#                                                                                     No
# 0                                                   1
# 1                                                   1
# 2                                                   1
# 3                                                   1
# 4                                                   -
# 5                                                   2
# 6                                                   -
# 7                                                   3
# 8                                                   3
# 9                                                   3
# 10                                                  4
# 11                                                  5
# 12                                                (3)
# ...

# %%
f[["Name","Party"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/7k/sc3lh9xn41n5c6p65w91_z240000gp/T/ipykernel_5495/3669868653.py in <module>
# ----> 1 f[["Name","Party"]]
#
# TypeError: list indices must be integers or slices, not list
